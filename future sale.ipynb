# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from googletrans import Translator

# %%
train_df = pd.read_csv('./sales_train.csv.gz')
test_df = pd.read_csv('./test.csv.gz')
item_categories_df = pd.read_csv('./item_categories.csv')
item_df = pd.read_csv('./items.csv')
shops_df = pd.read_csv('./shops.csv')
sample_submission_df = pd.read_csv('./sample_submission.csv.gz')

# %%
train_df = train_df.merge(item_df,how = 'inner')
test_df = test_df.merge(item_df,how = 'inner')
train_df = train_df.merge(shops_df,how = 'inner')
test_df = test_df.merge(shops_df,how = 'inner')

# %%
train_df_item = train_df.groupby('item_id')['item_cnt_day'].sum()
train_df_item.astype('float')
plt.figure(figsize=(16,8))
plt.title('Total Sale')
plt.xlabel('item')
plt.ylabel('Sales')
plt.plot(train_df_item)

# %%
practice_index_1 = train_df[(train_df['item_id']==20949) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_2 = train_df[(train_df['item_id']==2808) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_3 = train_df[(train_df['item_id']==3732) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_4 = train_df[(train_df['item_id']==17717) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_5 = train_df[(train_df['item_id']==5822) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_6 = train_df[(train_df['item_id']==1590) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_7 = train_df[(train_df['item_id']==13474) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_8 = train_df[(train_df['item_id']==11871) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_9 = train_df[(train_df['item_id']==18062) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_10 = train_df[(train_df['item_id']==13477) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_11 = train_df[(train_df['item_id']==7547) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_12 = train_df[(train_df['item_id']==8515) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_13 = train_df[(train_df['item_id']==4591) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_14 = train_df[(train_df['item_id']==3734) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_15 = train_df[(train_df['item_id']==6675) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_16 = train_df[(train_df['item_id']==3731) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_17 = train_df[(train_df['item_id']==1855) & (train_df['date_block_num']!=11) & (train_df['date_block_num']!=23) & (train_df['date_block_num']!=2)].index
practice_index_18 = train_df[train_df['date_block_num']==11].index
practice_index_19 = train_df[train_df['date_block_num']==23].index
practice_index_20 = train_df[train_df['date_block_num']==2].index

# %%
practice = train_df.drop(practice_index_1)
practice = practice.drop(practice_index_2)
practice = practice.drop(practice_index_3)
practice = practice.drop(practice_index_4)
practice = practice.drop(practice_index_5)
practice = practice.drop(practice_index_6)
practice = practice.drop(practice_index_7)
practice = practice.drop(practice_index_8)
practice = practice.drop(practice_index_9)
practice = practice.drop(practice_index_10)
practice = practice.drop(practice_index_11)
practice = practice.drop(practice_index_12)
practice = practice.drop(practice_index_13)
practice = practice.drop(practice_index_14)
practice = practice.drop(practice_index_15)
practice = practice.drop(practice_index_16)
practice = practice.drop(practice_index_17)
practice = practice.drop(practice_index_18)
practice = practice.drop(practice_index_19)
practice = practice.drop(practice_index_20)

# %%
train_df_item = practice.groupby('item_id')['item_cnt_day'].sum()
train_df_num.astype('float')
plt.figure(figsize=(16,8))
plt.title('Total Sale')
plt.xlabel('item')
plt.ylabel('Sales')
plt.plot(train_df_item)

# %%
train_df_num_1 = train_df.groupby('date_block_num')['item_cnt_day'].sum()
train_df_num_2 = practice.groupby('date_block_num')['item_cnt_day'].sum()
fig = plt.figure()
fig.set_size_inches(16,8)
ax_1 = fig.add_subplot(1,2,1)
ax_2 = fig.add_subplot(1,2,2)
ax_1.plot(train_df_num_1)
ax_2.plot(train_df_num_2)

# %%
train_df_all = practice.drop(columns=['shop_name','date','date_block_num','item_price','item_name','shop_name'])
test_df_all = test_df.drop(columns=['shop_name','item_name','shop_name'])
x_train = train_df_all
y_train = x_train.pop('item_cnt_day')

# %%
x_train = x_train.as_matrix()
y_train = y_train.as_matrix()
test_id_idx = test_df_all.pop('ID')
x_test = test_df_all.as_matrix()
# Out:
# C:\Users\soyeun\Miniconda3\envs\data_science\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# C:\Users\soyeun\Miniconda3\envs\data_science\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# C:\Users\soyeun\Miniconda3\envs\data_science\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
from sklearn import linear_model

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
submit = pd.DataFrame({'ID': test_id_idx, 'item_cnt_month': regr.predict(x_test)})
submit
# Out:
#             ID  item_cnt_month
# 0            0        1.263918
# 1            1        1.167623
# 2            2        1.263343
# 3            3        1.252739
# 4            4        1.260589
# 5            5        1.253305
# 6            6        1.261254
# 7            7        1.168426
# 8            8        1.167626
# 9            9        1.261366
# 10          10        1.235425
# 11          11        1.261835
# 12          12        1.169713
# 13          13        1.256455
# 14          14        1.253800
# 15          15        1.264402
# 16          16        1.123849
# 17          17        1.169505
# 18          18        1.235173
# 19          19        1.261480
# 20          20        1.169391
# 21          21        1.264021
# 22          22        1.219184
# 23          23        1.261640
# 24          24        1.232218
# 25          25        1.258715
# 26          26        1.250757
# 27          27        1.307222
# 28          28        1.304529
# ...

# %%
submit.to_csv('submission_future_sale.csv', index=False)
