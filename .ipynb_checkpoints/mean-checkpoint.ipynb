# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
item_cat=pd.read_csv("item_categories.csv")
item=pd.read_csv("items.csv")
sales = pd.read_csv("sales_train.csv.gz")
# sub=pd.read_csv("sample_submission.csv.gz")
shops=pd.read_csv("shops.csv")
test=pd.read_csv("test.csv.gz")

# %%
item_info = item.merge(item_cat)
x_data_df = pd.merge(sales, item_info, on='item_id')
x_data_df = pd.merge(x_data_df, shops, on='shop_id')

# %%
item_info.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 3        ***КОРОБКА (СТЕКЛО)                       D        4
# 4  ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
#
#    item_category_id item_category_name
# 0                40         Кино - DVD
# 1                40         Кино - DVD
# 2                40         Кино - DVD
# 3                40         Кино - DVD
# 4                40         Кино - DVD

# %%
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
x_data_df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 1  16.05.2013               4       59     2573       249.0           1.0
# 6  19.07.2013               6       59     2574       399.0           1.0
# 7  03.07.2013               6       59     2574       399.0           1.0
# 8  06.07.2013               6       59     2574       399.0           1.0
# 9  28.08.2013               7       59     2574       399.0           1.0
#
#                                            item_name  item_category_id  \
# 1                          DEL REY LANA  Born To Die                55
# 6  DEL REY LANA  Born To Die  The Paradise Editio...                55
# 7  DEL REY LANA  Born To Die  The Paradise Editio...                55
# 8  DEL REY LANA  Born To Die  The Paradise Editio...                55
# 9  DEL REY LANA  Born To Die  The Paradise Editio...                55
#
#                     item_category_name               shop_name
# ...

# %%
# 월별 item 판매 수
df = pd.DataFrame(x_data_df.groupby(['date_block_num'])['item_id'].count())
df.plot(figsize=(20,10))
### 11과 23에 이상값을 보임 --> 11은 13년도 말, 12또한 14년도 말

# %%
sales[sales['date_block_num']==11].head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1124316  04.12.2013              11       25    17769       199.0
# 1124317  15.12.2013              11       25    18016       500.0
# 1124318  22.12.2013              11       25    17763       399.0
# 1124319  31.12.2013              11       25    17760      3250.0
# 1124320  18.12.2013              11       25    17763       398.5
#
#          item_cnt_day
# 1124316           1.0
# 1124317           1.0
# 1124318           1.0
# 1124319           1.0
# 1124320           1.0

# %%
sales[sales['date_block_num']==23].head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2192637  24.12.2014              23       42    17279       299.0
# 2192638  27.12.2014              23       42    17315       399.0
# 2192639  24.12.2014              23       42    17315       399.0
# 2192640  21.12.2014              23       42    17315       399.0
# 2192641  20.12.2014              23       42    17315       399.0
#
#          item_cnt_day
# 2192637           1.0
# 2192638           1.0
# 2192639           1.0
# 2192640           1.0
# 2192641           2.0

# %%
# sales[sales['date_block_num']==10].head()

# %%
# 월별 shop_id 판매 수
df = pd.DataFrame(x_data_df.groupby(['date_block_num','shop_id'])['item_id'].count())
df.plot(figsize=(20,10))

# %%
# 3년간 item_id 판매 수
df = pd.DataFrame(x_data_df.groupby(['item_id'])['date'].count())
df.plot(figsize=(20,10))

# %%
pd.DataFrame(x_data_df.groupby(['item_id'])['date'].count()).sort_values(by=['date'], ascending=False)[:5]
# Out:
#           date
# item_id
# 20949    31340
# 5822      9408
# 17717     9067
# 2808      7479
# 4181      6853

# %%
df = x_data_df[x_data_df['item_id'] == 20949].groupby(['date'])['date_block_num'].count()
df.plot()

# %%
df = pd.DataFrame(x_data_df.groupby(['date_block_num'])['item_id'].count())
high_data_columns = df.sort_values(by=['item_id'], ascending=False)[:5].index
row_data_columns = df.sort_values(by=['item_id'], ascending=False)[-5:].index

# %%
x_data_df = x_data_df[~x_data_df.date_block_num.isin(high_data_columns)]
x_data_df = x_data_df[~x_data_df.date_block_num.isin(row_data_columns)]

# %%
# 월별 item 판매 수
df = pd.DataFrame(x_data_df.groupby(['date_block_num'])['item_id'].count())
df.plot(figsize=(20,10))
### 11과 23에 이상값을 보임

# %%
# 월별 shop_id 판매 수
df = pd.DataFrame(x_data_df.groupby(['date_block_num','shop_id'])['item_id'].count())
df.plot(figsize=(20,10))

# %%
# 3년간 item_id 판매 수
df = pd.DataFrame(x_data_df.groupby(['item_id'])['date'].count())
df.plot(figsize=(20,10))

# %%
X = pd.DataFrame(x_data_df.groupby(['date_block_num','shop_id','item_id'])['item_cnt_day'].count()).reset_index()
X.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_day
# 0               3        2       31             1
# 1               3        2      464             1
# 2               3        2      482             1
# 3               3        2      484             3
# 4               3        2      485             2

# %%
Y = X.pop('item_cnt_day')
X.pop('date_block_num')

# %%
X.head()
# Out:
#    shop_id  item_id
# 0        2       31
# 1        2      464
# 2        2      482
# 3        2      484
# 4        2      485

# %%
x_train.shape, y_train.shape, x_test.shape
# Out:
# ((1137572, 2), (1137572,), (214200, 2))

# %%
sales_x_train = sales[['date_block_num', 'shop_id','item_id','item_cnt_day']]
sales_13 = sales_x_train[:1267562]
sales_14 = sales_x_train[1267562:]
sales_month = pd.concat([sales_x_train[sales_x_train['date_block_num']==10], sales_x_train[sales_x_train['date_block_num']==22]])
sales_month = sales_month.drop(columns=['date_block_num'])

# %%
x_train = sales_month
y_train = x_train.pop('item_cnt_day')

# %%
# from keras.models import Sequential
# from keras.layers import Dense,Dropout
# from keras.layers import LSTM
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.metrics import mean_squared_error

# %%
# model = Sequential()
# model.add(Dense(8, input_dim=2, activation='relu'))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# model.fit(x_train, y_train, epochs=200, batch_size=2, verbose=2)

# %%
x_train.shape, y_train.shape, test.shape
# Out:
# ((183164, 2), (183164,), (214200, 2))

# %%
x_train = x_train.as_matrix()
y_train = y_train.as_matrix()
# test_id_idx = test.pop('ID')
x_test = test.as_matrix()
# Out:
# c:\users\lg\appdata\local\conda\conda\envs\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# c:\users\lg\appdata\local\conda\conda\envs\python\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# c:\users\lg\appdata\local\conda\conda\envs\python\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Build Model

# %%
from sklearn import linear_model

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Make predictions using the testing set
submit = pd.DataFrame({'ID': test_id_idx, 'item_cnt_month': regr.predict(x_test)})
submit.head()
# Out:
#    ID  item_cnt_month
# 0   0        1.422776
# 1   1        1.421956
# 2   2        1.422208
# 3   3        1.422211
# 4   4        1.422107

# %%
submit.to_csv('submission_mean.csv', index=False)
